# %%
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim 
import random 
import spacy
import datasets 
import torchtext
import tqdm
import evaluate

# %%
seed = 1234
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
# 确保程序的每次运行都具有确定性，可以得到相同的结果，用于程序的复现
torch.backends.cudnn.deterministic = True

# %% [markdown]
# #### Preparing Data
# - 获取数据集
# - tokenize, 加入special tokens
# - train_data's vocabulary
# - numerialize
# - with_format 修改index的数据类型

# %%
dataset = datasets.load_dataset("bentrevett/multi30k")
# print(dataset)
train_data, valid_data, test_data = (
    dataset["train"],
    dataset["validation"],
    dataset["test"],
)

# %%
# 数据集每条数据是一个字典，key：语种，value：对应的句子
print(train_data[0])
type(train_data[0])
# Out:
# {'en': 'Two young, White males are outside near many bushes.', 'de': 'Zwei junge weiße Männer sind im Freien in der Nähe vieler Büsche.'}
# dict

# %%
# tokenize
# 一种更为笼统的说法，包含了words, numbers, punctuations, any special symbol
# 利用spacy库加载两个用来处理德语/英语的模型
en_nlp = spacy.load("en_core_web_sm")
de_nlp = spacy.load("de_core_news_sm")

# %%
str = "What a lovely day it is today!"
[token.text for token in en_nlp.tokenizer(str)]
# Out:
# ['What', 'a', 'lovely', 'day', 'it', 'is', 'today', '!']

# %%
# 函数 接收example数据，对应的处理器，最大的长度，是否lower，句子的开始结尾token
def tokenizer_example(example, en_nlp, de_nlp, max_length, lower, sos_token, eos_token):
    en_tokens = [token.text for token in en_nlp.tokenizer(example["en"])][:max_length]
    de_tokens = [token.text for token in de_nlp.tokenizer(example["de"])][:max_length]
    if lower:
        en_tokens = [token.lower() for token in en_tokens]
        de_tokens = [token.lower() for token in de_tokens]
    en_tokens = [sos_token] + en_tokens + [eos_token]
    de_tokens = [sos_token] + de_tokens + [eos_token]
    return {"en_tokens" : en_tokens, "de_tokens" : de_tokens}

# %%
max_length = 1000
sos_token = "<sos>"
eos_token = "<eos>"
lower = True 

fn_kwargs = {
    "en_nlp" : en_nlp,
    "de_nlp" : de_nlp,
    "max_length" : max_length,
    "lower" : lower,
    "sos_token" : sos_token,
    "eos_token" : eos_token,
}

# 通过调用tokenizer_example函数并传入对应的参数字典，来向dataset中添加函数返回的key-value
train_data = train_data.map(tokenizer_example, fn_kwargs=fn_kwargs)
valid_data = valid_data.map(tokenizer_example, fn_kwargs=fn_kwargs)
test_data = test_data.map(tokenizer_example, fn_kwargs=fn_kwargs)
# Out:
# Map:   0%|          | 0/1014 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %%
train_data[0]
# Out:
# {'en': 'Two young, White males are outside near many bushes.',
#  'de': 'Zwei junge weiße Männer sind im Freien in der Nähe vieler Büsche.',
#  'en_tokens': ['<sos>',
#   'two',
#   'young',
#   ',',
#   'white',
#   'males',
#   'are',
#   'outside',
#   'near',
#   'many',
#   'bushes',
#   '.',
#   '<eos>'],
#  'de_tokens': ['<sos>',
#   'zwei',
#   'junge',
#   'weiße',
#   'männer',
#   'sind',
#   'im',
#   'freien',
#   'in',
#   'der',
#   'nähe',
#   'vieler',
#   'büsche',
#   '.',
#   '<eos>']}

# %%
# vocabularies 
# 生成token和index之间的映射字典，传入神经网络的是这些映射整数
# 理论上说，生成的字母表应该包含所有可能出现的token，但是如果token不出现在train_data中但是出现在test_data或者valid_data中呢
# 引入<unk> unkown token，其对应的index通常是一个固定的数，比如0，用来表示那些在vocabulary中无法找到的token

# 出现次数小于min_freq的应该被tokenize为<unk>，人为在train_data中添加了<unk>的token
min_freq = 2
unk_token = "<unk>"
# 每次输入一个batch，batch中的句子长度应该在传入时与这一批中的最大长度相同，转化为token时自动padding
pad_token = "<pad>"
special_tokens = [
    sos_token,
    eos_token,
    unk_token,
    pad_token,
]

# vocabulary 只能在train_data上建立，防止信息泄露
en_vocab = torchtext.vocab.build_vocab_from_iterator(
    train_data["en_tokens"],
    min_freq=min_freq,
    specials=special_tokens,
)

de_vocab = torchtext.vocab.build_vocab_from_iterator(
    train_data["de_tokens"],
    min_freq=min_freq,
    specials=special_tokens,
)

# %%
# 这表示int to string的前十个，可以切片，因为是存在list中
en_vocab.get_itos()[:10]
# Out:
# ['<sos>', '<eos>', '<unk>', '<pad>', 'a', '.', 'in', 'the', 'on', 'man']

# %%
# 无法切片因为是dict
en_vocab.get_stoi()
# Out:
# {'company': 1869,
#  'metal': 307,
#  'green': 52,
#  'track': 302,
#  'pours': 2356,
#  'vase': 5829,
#  'the': 7,
#  'crashes': 3951,
#  'non': 5340,
#  'bonding': 4685,
#  'face': 158,
#  'doll': 1775,
#  'garbage': 1120,
#  'workers': 228,
#  'winter': 446,
#  'taste': 3737,
#  'seems': 1207,
#  'outdoors': 341,
#  'her': 44,
#  'activity': 1973,
#  'hose': 834,
#  'turbulent': 5808,
#  'group': 38,
#  'gentleman': 524,
#  'bald': 683,
#  'underway': 4509,
#  'a': 4,
#  'scaffolds': 5551,
#  'outside': 57,
#  'drivers': 3393,
#  'readying': 3612,
#  'jeans': 175,
#  'black': 26,
#  'to': 18,
#  'jungle': 1235,
#  'supervision': 5722,
#  'or': 258,
#  'all': 255,
#  'examined': 4955,
#  'observes': 1725,
#  'i': 956,
#  'ball': 68,
#  'sandwich': 1293,
#  '<sos>': 0,
#  'cheerleaders': 927,
#  'fisherman': 1421,
#  'firetruck': 1419,
#  'sunrise': 3726,
#  'pub': 2816,
#  'fires': 4989,
#  'sing': 1209,
#  'street': 39,
#  'moped': 1504,
#  'in': 6,
#  'customers': 850,
#  'sheepdog': 3654,
#  'taping': 5747,
#  'mood': 5309,
#  'attire': 453,
#  'kicked': 2761,
#  'probably': 2812,
#  'soccer': 123,
#  '<pad>': 3,
#  'crane': 1480,
#  'smoke': 1346,
#  'york': 1105,
#  'lowering': 5250,
#  'hiding': 2022,
#  'cowboy': 429,
#  'storage': 3710,
#  'daily': 2466,
#  'kimono': 5199,
#  'cottage': 4837,
#  '<eos>': 1,
#  '.': 5,
#  'woods': 440,
#  'little': 53,
#  'newspapers': 1802,
#  '<unk>': 2,
#  'pushes': 940,
#  'presses': 4305,
#  'moved': 4223,
#  'burning': 1858,
#  'helicopter': 2021,
#  'water': 47,
#  'accompanies': 3818,
#  'raises': 1518,
#  'decorations': 2126,
#  'toast': 3754,
#  'girls': 104,
#  'crashing': 2280,
#  'on': 8,
#  'motorbike': 1505,
#  'again': 3826,
#  'slides': 1345,
#  'produce': 893,
#  'district': 4903,
#  'brown': 61,
#  'flowers': 367,
#  'writing': 680,
#  'together': 129,
#  'walkway': 679,
#  'subject': 5715,
#  'strange': 1948,
#  'gymnasium': 1495,
#  'squares': 3695,
#  'dancing': 239,
#  'flips': 1708,
#  'math': 5276,
#  'sitting': 32,
#  'eagle': 4925,
#  'coeds': 4803,
#  'adult': 387,
#  'stunt': 823,
#  'horses': 494,
#  'man': 9,
#  'structures': 3717,
#  'swamp': 5733,
#  'dolly': 3385,
#  'near': 80,
#  'cart': 271,
#  'airplane': 1016,
#  'playing': 37,
#  'shake': 4389,
#  'forehead': 1781,
#  'other': 72,
#  'mittens': 2782,
#  'punching': 2563,
#  'fountain': 383,
#  'down': 40,
#  'short': 386,
#  'companion': 2278,
#  'standing': 36,
#  'tee': 1671,
#  'appears': 477,
#  'woman': 14,
#  'merchant': 3109,
#  'mob': 5304,
#  'tired': 2228,
#  'poses': 436,
#  'plaid': 384,
#  'balls': 810,
#  'is': 10,
#  'band': 200,
#  'white': 25,
#  'an': 21,
#  'curly': 867,
#  'helping': 727,
#  'traffic': 783,
#  'chili': 4768,
#  'and': 11,
#  'conversation': 566,
#  'sorts': 3684,
#  'moose': 4219,
#  'outfit': 300,
#  'being': 191,
#  'sprinklers': 2863,
#  'of': 12,
#  'bike': 99,
#  'swing': 308,
#  'bottle': 531,
#  'wooded': 902,
#  'sees': 4380,
#  'apart': 1976,
#  'ladder': 576,
#  'yellow': 62,
#  'technique': 3742,
#  'enthusiastically': 3407,
#  'leaves': 513,
#  'dog': 35,
#  'proud': 4314,
#  'squatting': 1394,
#  'barriers': 2660,
#  'open': 310,
#  'seated': 450,
#  'door': 532,
#  'flotation': 4060,
#  'ribbon': 1441,
#  'siding': 3658,
#  'after': 376,
#  'acrobat': 4569,
#  'with': 13,
#  'men': 30,
#  'slip': 3669,
#  'fashionable': 3415,
#  ',': 15,
#  'taxi': 1596,
#  'hikers': 932,
#  'two': 16,
#  'friend': 851,
#  'as': 58,
#  'await': 2426,
#  'blue': 29,
#  'medals': 5280,
#  'are': 17,
#  'people': 19,
#  'boards': 1983,
#  'slope': 944,
#  'at': 20,
#  'chopsticks': 2115,
#  'flies': 831,
#  'beards': 3295,
#  'thought': 3749,
#  'amusement': 1182,
#  'children': 63,
#  'interested': 4129,
#  'meat': 740,
#  'hooded': 1161,
#  'buildings': 470,
#  'wearing': 22,
#  'shirt': 23,
#  'frisbee': 409,
#  'raise': 2822,
#  'pushing': 410,
#  'three': 48,
#  'chores': 4777,
#  'into': 69,
#  't': 208,
#  'tour': 2398,
#  'laid': 2514,
#  'fish': 442,
#  'trail': 438,
#  'fetch': 2494,
#  'sloping': 3670,
#  'shouts': 5607,
#  'without': 879,
#  'fallen': 974,
#  'sculptor': 3644,
#  'girl': 33,
#  'boutique': 4693,
#  'young': 24,
#  'punch': 2360,
#  'ponchos': 4294,
#  'play': 128,
#  'overweight': 1729,
#  'backpack': 343,
#  'james': 5182,
#  'nicely': 3119,
#  'his': 27,
#  'here': 832,
#  'tux': 5811,
#  'herself': 1324,
#  'toward': 458,
#  'stilts': 2069,
#  'skeleton': 3663,
#  'ladders': 3490,
#  'home': 545,
#  'while': 28,
#  'pot': 1001,
#  'mouth': 203,
#  'propeller': 5460,
#  'red': 31,
#  'makeshift': 3100,
#  'brother': 1986,
#  'uses': 579,
#  'filed': 4984,
#  'completing': 2456,
#  'boy': 34,
#  'computer': 418,
#  'riding': 78,
#  'facility': 2010,
#  '-': 42,
#  'scattered': 2840,
#  'beneath': 1537,
#  'swimsuit': 1101,
#  'boats': 1110,
#  'walking': 41,
#  'course': 701,
#  'skin': 4402,
#  'photography': 3565,
#  'rows': 1936,
#  'container': 1366,
#  'skirt': 451,
#  'made': 730,
#  'joggers': 3479,
#  'race': 164,
#  'olympic': 2176,
#  'front': 43,
#  'crabs': 4842,
#  'for': 54,
#  'haired': 210,
#  'missed': 5300,
#  'belt': 1403,
#  'campers': 2963,
#  'wool': 3805,
#  'corner': 406,
#  'special': 2861,
#  'cow': 928,
#  'painter': 2178,
#  'manner': 5261,
#  'holding': 45,
#  'referee': 1206,
#  'drinking': 351,
#  'discussing': 1484,
#  'artwork': 1853,
#  'kiddie': 3484,
#  'one': 46,
#  'hot': 600,
#  'designs': 2128,
#  'cityscape': 2984,
#  'cups': 1697,
#  'smiles': 346,
#  'by': 49,
#  'large': 59,
#  'still': 1828,
#  'graduation': 3446,
#  'sort': 688,
#  'women': 50,
#  'loaded': 2331,
#  'flame': 4993,
#  'up': 51,
#  'geese': 4075,
#  'rise': 4354,
#  'driving': 506,
#  'tags': 2220,
#  'science': 1816,
#  'child': 55,
#  'friends': 486,
#  'stone': 333,
#  'apparatus': 2917,
#  'through': 60,
#  'looking': 56,
#  'assorted': 4619,
#  'number': 448,
#  'darth': 4871,
#  'cooked': 3356,
#  'hand': 139,
#  'material': 1564,
#  'person': 64,
#  'bmx': 1185,
#  'from': 65,
#  'substance': 3720,
#  'backwards': 1108,
#  'arm': 394,
#  'times': 2395,
#  'surfboard': 649,
#  'kid': 348,
#  'pocket': 2354,
#  'plush': 3148,
#  'europe': 2294,
#  'toy': 223,
#  'firefighters': 1227,
#  'ally': 3830,
#  'wet': 586,
#  'motion': 2172,
#  'excitement': 3036,
#  'pork': 5438,
#  'their': 66,
#  'perform': 508,
#  'scouts': 1939,
#  'hat': 67,
#  'enjoying': 304,
#  'baked': 2936,
#  'small': 70,
#  'aged': 433,
#  'handrail': 2019,
#  'next': 71,
#  'cafe': 720,
#  'buys': 4733,
#  'handing': 1785,
#  'orchestra': 1202,
#  'beach': 88,
#  'rowers': 4361,
#  'dressed': 73,
#  'button': 950,
#  'shoppers': 1822,
#  'berlin': 3877,
#  'rodgers': 5526,
#  'chin': 2453,
#  'country': 664,
#  'lecture': 1795,
#  'flute': 1709,
#  'coach': 1314,
#  'desks': 2471,
#  'some': 74,
#  'goods': 1121,
#  'river': 309,
#  'hardwood': 2313,
#  'out': 75,
#  'lion': 2520,
#  'ride': 281,
#  'items': 581,
#  'talk': 689,
#  'listens': 1502,
#  'quaint': 3606,
#  'over': 76,
#  'downtown': 1546,
#  'bump': 4721,
#  'building': 77,
#  'horseback': 1326,
#  'balancing': 1044,
#  'freight': 5016,
#  'tattoo': 825,
#  'island': 3080,
#  'swimmers': 1595,
#  'running': 79,
#  'around': 83,
#  'escalator': 1157,
#  'facade': 4038,
#  'lost': 3096,
#  'police': 362,
#  'mrs.': 5319,
#  'pinstriped': 3147,
#  'varying': 3249,
#  'jacket': 81,
#  'rides': 241,
#  'talks': 540,
#  'keyboard': 1088,
#  'amongst': 1533,
#  'another': 82,
#  'participants': 3555,
#  'inner': 4128,
#  'sidewalk': 84,
#  'column': 2697,
#  'mike': 4212,
#  'field': 85,
#  'kayaker': 3480,
#  'african': 324,
#  'orange': 86,
#  'cast': 2973,
#  'camera': 116,
#  'shops': 1660,
#  'crowd': 87,
#  'denim': 1049,
#  'downwards': 4910,
#  'photos': 1576,
#  'stands': 89,
#  'beverages': 1762,
#  'bikini': 590,
#  'dunk': 3398,
#  'inside': 280,
#  'lens': 2031,
#  'pink': 90,
#  'sprinkled': 4429,
#  'hula': 886,
#  'topic': 3755,
#  'sits': 91,
#  'soldering': 3679,
#  'pushed': 2817,
#  'pose': 403,
#  'supermarket': 2605,
#  'doorstep': 4907,
#  'tag': 1349,
#  'jumping': 92,
#  'skinned': 1099,
#  'printed': 1929,
#  'behind': 93,
#  'table': 94,
#  'rink': 1442,
#  'looks': 107,
#  'decker': 3971,
#  'cellphone': 286,
#  'fives': 3423,
#  'snow': 95,
#  'grass': 96,
#  'teammate': 1597,
#  'lined': 474,
#  'hair': 97,
#  'puppies': 1811,
#  'spin': 3693,
#  'hardware': 5085,
#  'bench': 144,
#  'win': 2415,
#  'instruments': 423,
#  'background': 98,
#  'examining': 1191,
#  'stunning': 5711,
#  'father': 665,
#  'clap': 2692,
#  'projector': 2358,
#  'scuba': 1248,
#  'sand': 211,
#  'mixture': 5302,
#  'downward': 4909,
#  'photo': 342,
#  'stand': 100,
#  'city': 101,
#  'tap': 3736,
#  'clear': 1022,
#  'cotton': 2461,
#  'gas': 1493,
#  'yamaha': 3810,
#  'both': 405,
#  'bite': 1763,
#  'sweet': 4460,
#  'vehicle': 529,
#  'haircut': 1229,
#  "'s": 102,
#  'air': 103,
#  'wigs': 3802,
#  'nap': 1130,
#  'work': 245,
#  'filling': 1780,
#  'written': 2905,
#  'younger': 530,
#  'wakeboards': 5849,
#  'tugging': 3241,
#  'player': 105,
#  'dragster': 4911,
#  'marathon': 644,
#  'positioned': 3152,
#  'security': 1588,
#  'gathered': 359,
#  'luggage': 1029,
#  'asian': 106,
#  'cheers': 3925,
#  'cap': 283,
#  '2': 417,
#  'signs': 696,
#  'cheek': 1865,
#  'wall': 108,
#  'top': 109,
#  'buoy': 3318,
#  'dance': 330,
#  'east': 2136,
#  'dark': 178,
#  'ballet': 1758,
#  'screwdriver': 4376,
#  'four': 110,
#  'excited': 1415,
#  'rodeo': 560,
#  'off': 111,
#  'released': 4341,
#  'opens': 1917,
#  'took': 4479,
#  'dogs': 112,
#  'gift': 1630,
#  'mechanic': 3515,
#  'several': 113,
#  'strike': 2869,
#  'elmo': 2138,
#  'that': 114,
#  'jogging': 854,
#  'older': 115,
#  'sleeps': 822,
#  'taking': 165,
#  'reporters': 5508,
#  'arcade': 1852,
#  'toil': 5782,
#  'this': 209,
#  'mix': 2337,
#  'eight': 1269,
#  'airport': 1148,
#  'it': 141,
#  'wicker': 3801,
#  'dress': 117,
#  'warming': 2631,
#  'audio': 3850,
#  'park': 118,
#  'talking': 119,
#  'weeds': 3795,
#  'students': 521,
#  'rocket': 5525,
#  'lady': 120,
#  'five': 251,
#  'apron': 502,
#  'sunlight': 1949,
#  'burgundy': 1686,
#  'quickly': 2055,
#  'pump': 4319,
#  'something': 121,
#  'handbag': 2746,
#  'rose': 5529,
#  'blond': 122,
#  'chases': 951,
#  'art': 511,
#  'along': 124,
#  'last': 3088,
#  'binder': 4666,
#  'cobblestone': 1621,
#  'dreadlocks': 1413,
#  'oriental': 937,
#  'mugs': 5320,
#  'devil': 4890,
#  'walks': 125,
#  'outfits': 693,
#  'between': 412,
#  'grill': 507,
#  'facing': 618,
#  'individuals': 835,
#  'express': 4961,
#  'guitar': 126,
#  'washing': 760,
#  'trying': 260,
#  'mesmerized': 4207,
#  'theater': 1527,
#  'van': 809,
#  'oh': 5354,
#  'attempting': 682,
#  'boys': 127,
#  'working': 130,
#  'during': 226,
#  'aprons': 2090,
#  'tattered': 3739,
#  'islamic': 5174,
#  'food': 131,
#  'mud': 741,
#  'purses': 2361,
#  'champagne': 2978,
#  'textile': 5760,
#  'gray': 132,
#  'process': 2052,
#  'sexy': 4385,
#  'bagpipes': 1757,
#  'shrimp': 4393,
#  'mother': 496,
#  'surgery': 1951,
#  'smiling': 133,
#  'sweater': 317,
#  'tan': 282,
#  'watering': 2895,
#  'book': 277,
#  'films': 4048,
#  'picture': 134,
#  'getting': 257,
#  'inspectors': 5160,
#  'hammer': 992,
#  'straight': 1669,
#  'binoculars': 1614,
#  'game': 135,
#  'treat': 2230,
#  'completes': 4815,
#  'has': 136,
#  'member': 1435,
#  'mug': 1915,
#  'sleeveless': 1445,
#  'walk': 152,
#  'including': 871,
#  'masonry': 5269,
#  'fed': 4042,
#  'reaching': 780,
#  'series': 2367,
#  'plays': 137,
#  'china': 1867,
#  'cliff': 479,
#  'resting': 841,
#  'operated': 2795,
#  'wheelchair': 1070,
#  'sun': 427,
#  'car': 138,
#  'kissing': 659,
#  'locomotives': 5243,
#  'holds': 140,
#  'skier': 648,
#  'grabbing': 2149,
#  'cones': 1047,
#  'vertical': 3251,
#  'reading': 218,
#  'dancers': 747,
#  'road': 142,
#  'ended': 4939,
#  'carriage': 1113,
#  'house': 356,
#  'think': 3747,
#  'package': 2348,
#  'climbs': 643,
#  'free': 1424,
#  'featured': 4041,
#  'laying': 273,
#  'beating': 2432,
#  'beard': 441,
#  'him': 143,
#  'path': 288,
#  'padding': 3549,
#  'chasing': 656,
#  'award': 2656,
#  'old': 145,
#  'knees': 1793,
#  'angels': 2914,
#  'rural': 1443,
#  'glasses': 146,
#  'skate': 744,
#  'peeling': 3564,
#  'francisco': 5013,
#  'night': 305,
#  'oxen': 3547,
#  'very': 262,
#  'late': 2766,
#  'bikes': 449,
#  'vegas': 3780,
#  'bathed': 3865,
#  'pants': 147,
#  'tutus': 4501,
#  'pulling': 475,
#  'toss': 4481,
#  'shorts': 148,
#  'stage': 149,
#  'enthusiastic': 4947,
#  'sit': 150,
#  'view': 428,
#  'cupcakes': 3369,
#  'carrying': 151,
#  'microphone': 220,
#  'poised': 3580,
#  'watched': 1968,
#  'baby': 153,
#  'couple': 154,
#  'competing': 617,
#  'boarding': 2668,
#  'celebrating': 1362,
#  'them': 155,
#  'shallow': 792,
#  'swaddled': 5731,
#  'village': 1605,
#  'paddled': 5373,
#  'plastic': 431,
#  'carpeted': 3328,
#  'fashioned': 1887,
#  'sunhat': 3725,
#  'side': 156,
#  'forrest': 4066,
#  'ornate': 1383,
#  'bicycle': 157,
#  'meal': 596,
#  'mini': 2532,
#  'swims': 983,
#  'jack': 2757,
#  'no': 549,
#  'lipstick': 2771,
#  'maneuvering': 4191,
#  'knife': 1794,
#  'bun': 4722,
#  'turn': 967,
#  'jerseys': 1124,
#  'tree': 159,
#  'similarly': 3660,
#  'dust': 1777,
#  '"': 160,
#  'male': 161,
#  'pool': 162,
#  'flashlight': 4054,
#  'grin': 5061,
#  'long': 163,
#  'blocked': 2949,
#  'rock': 166,
#  'court': 493,
#  'each': 167,
#  'rad': 5476,
#  'coached': 4797,
#  'wood': 424,
#  'quietly': 5472,
#  'headscarf': 1278,
#  'touch': 1957,
#  'where': 476,
#  'middle': 168,
#  'opposite': 1030,
#  'doing': 169,
#  'british': 2440,
#  'equestrian': 3034,
#  'pillow': 1651,
#  'robes': 1006,
#  'public': 420,
#  'dirt': 170,
#  'half': 1276,
#  'across': 171,
#  'tables': 708,
#  'head': 172,
#  'vests': 468,
#  'paris': 5385,
#  'barrier': 1682,
#  'forest': 397,
#  'watching': 173,
#  'coveralls': 3359,
#  'bystanders': 1687,
#  'crown': 2709,
#  'heads': 768,
#  'rice': 1934,
#  'guy': 174,
#  'beanie': 1760,
#  'seesaw': 3181,
#  'bmw': 3882,
#  'there': 176,
#  'area': 177,
#  'motorcyclists': 1912,
#  'skateboarder': 480,
#  'strapped': 2216,
#  'room': 187,
#  'jumps': 179,
#  'photographers': 2352,
#  'fuzzy': 2504,
#  'dirty': 765,
#  'dj': 1880,
#  'waring': 3788,
#  'despite': 3381,
#  'boat': 180,
#  'numbers': 2042,
#  'pony': 2355,
#  'hands': 181,
#  'emergency': 1487,
#  'swampy': 3730,
#  'many': 202,
#  'back': 182,
#  'boxers': 2674,
#  'female': 183,
#  'whistle': 2900,
#  'cement': 626,
#  'rowing': 1292,
#  'day': 184,
#  'shopping': 332,
#  'papers': 1573,
#  'alley': 641,
#  'storefronts': 3213,
#  'eyeliner': 4964,
#  'ground': 185,
#  'driveway': 2006,
#  'performing': 186,
#  'fun': 816,
#  'second': 1940,
#  'applying': 1755,
#  'curious': 3370,
#  'dinner': 884,
#  'parachutes': 3130,
#  'karaoke': 4143,
#  'interior': 4130,
#  'window': 240,
#  'emerges': 3033,
#  'places': 1809,
#  'shows': 821,
#  'baseball': 188,
#  'stripes': 1454,
#  'waterway': 1749,
#  'lane': 1329,
#  'pointing': 609,
#  'movie': 1800,
#  'what': 459,
#  'pitching': 2805,
#  'light': 299,
#  'turkey': 2621,
#  'money': 1198,
#  'who': 189,
#  'muscular': 2342,
#  'shapes': 3651,
#  'eggs': 1704,
#  'preparing': 370,
#  'sweatpants': 5736,
#  'leashed': 5223,
#  'eating': 190,
#  'selling': 395,
#  'barefooted': 2253,
#  'jackets': 555,
#  'football': 192,
#  'coat': 193,
#  'placed': 1923,
#  'foliage': 2144,
#  'fill': 2496,
#  'striped': 194,
#  'using': 195,
#  'pockets': 4290,
#  'kids': 196,
#  'toys': 773,
#  'machete': 4188,
#  'hard': 325,
#  '%': 4557,
#  'baskets': 1306,
#  'leaps': 601,
#  'helmet': 234,
#  'devices': 2714,
#  'suit': 197,
#  'buck': 4711,
#  'indian': 554,
#  'breakfast': 3895,
#  'provide': 4316,
#  'horse': 198,
#  'structure': 520,
#  'progress': 2814,
#  'clothing': 219,
#  'lifted': 1903,
#  'seeds': 3648,
#  'under': 199,
#  'smelling': 5644,
#  'arena': 1017,
#  'faced': 4039,
#  'hatchet': 5089,
#  'tasty': 4466,
#  'main': 2775,
#  'watch': 201,
#  'fireplace': 3045,
#  'truck': 276,
#  'purple': 204,
#  'he': 205,
#  'fence': 268,
#  'restaurant': 235,
#  'spongebob': 3205,
#  'cars': 492,
#  'excitedly': 2723,
#  'mouse': 2784,
#  'way': 710,
#  'sign': 206,
#  'vacuuming': 2628,
#  'store': 207,
#  'calf': 1408,
#  'have': 414,
#  'runs': 212,
#  'tennis': 213,
#  'stops': 1829,
#  'look': 214,
#  'snowdrift': 5650,
#  'speak': 1947,
#  'players': 215,
#  'works': 465,
#  'interacting': 1636,
#  'neighborhood': 1335,
#  'ramp': 432,
#  'packs': 5372,
#  'school': 456,
#  'construction': 216,
#  'sunglasses': 217,
#  'towards': 301,
#  'reads': 455,
#  'content': 3941,
#  'michael': 5289,
#  'cyclist': 868,
#  'mountain': 221,
#  'observed': 4239,
#  'examines': 1706,
#  'mates': 3514,
#  'covered': 222,
#  'kissed': 4150,
#  'basketball': 224,
#  'gazes': 2017,
#  'bag': 265,
#  'ocean': 225,
#  'mower': 1914,
#  'slot': 3671,
#  'props': 5461,
#  'boaters': 4683,
#  'discuss': 2474,
#  'drink': 413,
#  'statue': 443,
#  'its': 227,
#  'nibbles': 5337,
#  'india': 2320,
#  'birthday': 1355,
#  'mule': 2785,
#  'motorcycle': 295,
#  'watches': 229,
#  'resort': 2573,
#  'protect': 2359,
#  'climbing': 230,
#  'soap': 2210,
#  'uniform': 231,
#  'past': 232,
#  'sedan': 4378,
#  'waiting': 254,
#  'seat': 1097,
#  'target': 1741,
#  'bat': 848,
#  'elderly': 233,
#  'gym': 726,
#  'sleeping': 375,
#  'pruning': 4317,
#  'tires': 1745,
#  'against': 236,
#  'powder': 3589,
#  'sunny': 396,
#  'formation': 1892,
#  'closely': 1868,
#  'garage': 1273,
#  'team': 237,
#  'train': 238,
#  'vision': 5839,
#  'filled': 473,
#  'unseen': 3775,
#  'link': 2034,
#  'skateboarding': 584,
#  'decked': 4877,
#  'shop': 316,
#  'bridge': 365,
#  'shirts': 242,
#  'lining': 2519,
#  'march': 2038,
#  'gentlemen': 975,
#  'protective': 1003,
#  'snaps': 3196,
#  'fold': 3430,
#  'chair': 243,
#  'surroundings': 3728,
#  'pitcher': 939,
#  'they': 244,
#  'bunny': 2680,
#  'hangs': 1025,
#  'about': 246,
#  'sips': 4398,
#  'tub': 1256,
#  'be': 247,
#  'see': 1007,
#  'collar': 721,
#  'diving': 748,
#  'canal': 2265,
#  'leave': 5224,
#  'teenage': 732,
#  'consoles': 4820,
#  'picnic': 916,
#  'blazer': 1981,
#  'exercise': 1778,
#  'mounds': 5314,
#  'engine': 1551,
#  'wooden': 248,
#  'wrestle': 1606,
#  'posing': 249,
#  ...}

# %%
en_vocab.get_stoi()["in"]
# Out:
# 6

# %%
# 还可以直接写成
en_vocab["in"]
# Out:
# 6

# %%
len(de_vocab), len(en_vocab)
# Out:
# (7853, 5893)

# %%
# "The" 中含有大写字母一定不在en_vocab中
print("The" in en_vocab)
# en_vocab["The"] # 会报错，可以设置这个值，在取不存在与vocab中的单词时返回
# Out:
# False

# %%
# vocab 中<unk>的index不一定是0，与specials参数中的顺序有关
assert en_vocab[pad_token] == de_vocab[pad_token]
assert en_vocab[unk_token] == de_vocab[unk_token]

unk_index = en_vocab[unk_token]
pad_index = en_vocab[pad_token]

# %%
# 上面在取vocabulary之外的值时，就会报错，这里设置默认的不在vocabulary中的token的index值为unk_index
en_vocab.set_default_index(unk_index)
de_vocab.set_default_index(unk_index)

# %%
en_vocab["The"]
# Out:
# 2

# %%
# 一个有用的method，lookup_indeces，接收一个token list返回对应的index

tokens = ["i", "love", "watching", "crime", "shows"]
en_vocab.lookup_indices(tokens)
# Out:
# [956, 2169, 173, 2, 821]

# %%
# 相应的lookup_tokens
en_vocab.lookup_tokens(en_vocab.lookup_indices(tokens))
# Out:
# ['i', 'love', 'watching', '<unk>', 'shows']

# %%
# 类似tokenize_example，写一个numericalize_example通过map应用
def numericalize_example(example, en_vocab, de_vocab):
    en_ids = en_vocab.lookup_indices(example["en_tokens"])
    de_ids = de_vocab.lookup_indices(example["de_tokens"])
    return {"en_ids" : en_ids, "de_ids" : de_ids}

# %%
# fn_kwargs 是function_keyword arguments的缩写
fn_kwargs = {"en_vocab" : en_vocab, "de_vocab" : de_vocab}
train_data = train_data.map(numericalize_example, fn_kwargs=fn_kwargs)
valid_data = valid_data.map(numericalize_example, fn_kwargs=fn_kwargs)
test_data = test_data.map(numericalize_example, fn_kwargs=fn_kwargs)
# Out:
# Map:   0%|          | 0/1014 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %%
train_data[0]
# Out:
# {'en': 'Two young, White males are outside near many bushes.',
#  'de': 'Zwei junge weiße Männer sind im Freien in der Nähe vieler Büsche.',
#  'en_tokens': ['<sos>',
#   'two',
#   'young',
#   ',',
#   'white',
#   'males',
#   'are',
#   'outside',
#   'near',
#   'many',
#   'bushes',
#   '.',
#   '<eos>'],
#  'de_tokens': ['<sos>',
#   'zwei',
#   'junge',
#   'weiße',
#   'männer',
#   'sind',
#   'im',
#   'freien',
#   'in',
#   'der',
#   'nähe',
#   'vieler',
#   'büsche',
#   '.',
#   '<eos>'],
#  'en_ids': [0, 16, 24, 15, 25, 778, 17, 57, 80, 202, 1312, 5, 1],
#  'de_ids': [0, 18, 26, 253, 30, 84, 20, 88, 7, 15, 110, 7647, 3171, 4, 1]}

# %%
# 检查一些是否对应
en_vocab.lookup_tokens(train_data[0]['en_ids'])
# Out:
# ['<sos>',
#  'two',
#  'young',
#  ',',
#  'white',
#  'males',
#  'are',
#  'outside',
#  'near',
#  'many',
#  'bushes',
#  '.',
#  '<eos>']

# %%
# 目前的index都是python的内置int类型，希望转化为"torch" for Pytorch
data_type = "torch"
format_columns = ["en_ids", "de_ids"]
# with_format method把对应的columns转化为type类型，默认是只返回columns中包含的features
# 设置output_all_columns=True，可以保留所有的特征
train_data = train_data.with_format(
    type=data_type,
    columns=format_columns,
    output_all_columns=True,
)

valid_data = valid_data.with_format(
    type=data_type,
    columns=format_columns,
    output_all_columns=True,
)
test_data = test_data.with_format(
    type=data_type,
    columns=format_columns,
    output_all_columns=True,
)

# %%
train_data[0]
# Out:
# {'en_ids': tensor([   0,   16,   24,   15,   25,  778,   17,   57,   80,  202, 1312,    5,
#             1]),
#  'de_ids': tensor([   0,   18,   26,  253,   30,   84,   20,   88,    7,   15,  110, 7647,
#          3171,    4,    1]),
#  'en': 'Two young, White males are outside near many bushes.',
#  'de': 'Zwei junge weiße Männer sind im Freien in der Nähe vieler Büsche.',
#  'en_tokens': ['<sos>',
#   'two',
#   'young',
#   ',',
#   'white',
#   'males',
#   'are',
#   'outside',
#   'near',
#   'many',
#   'bushes',
#   '.',
#   '<eos>'],
#  'de_tokens': ['<sos>',
#   'zwei',
#   'junge',
#   'weiße',
#   'männer',
#   'sind',
#   'im',
#   'freien',
#   'in',
#   'der',
#   'nähe',
#   'vieler',
#   'büsche',
#   '.',
#   '<eos>']}

# %%
# 每个batch进行padding处理,collate means collect and combine

# 传入的参数是用来padding的index，返回一个函数collate_fn
# closure闭包的写法，让内部的函数能够持续地使用pad_index，而不用创建全局变量或者创建一个类
def get_collate_fn(pad_index):
    # 返回一个字典，分开的batch（两个语言分开），已经使用pad_index padding使得所有长度与原长度最大相等，传入的参数是一个batch大小的data
    def collate_fn(batch):
        batch_en_ids = [example['en_ids'] for example in batch]
        batch_de_ids = [example['de_ids'] for example in batch]
        # batch_first=False（默认为False），返回的数据size就是[max_length, batch_size]的，也就是每一列是padding后的
        # numericalize 的sequence，如果设置batch_first=True，那么返回的数据就是[batch_size, max_length]符合每一行是seq的直觉
        batch_en_ids = nn.utils.rnn.pad_sequence(batch_en_ids, padding_value=pad_index)
        batch_de_ids = nn.utils.rnn.pad_sequence(batch_de_ids, padding_value=pad_index)
        return {"en_ids" : batch_en_ids, "de_ids" : batch_de_ids}
    return collate_fn

# %%
# 利用Pytorch的DataLoader
def get_data_loader(dataset, batch_size, pad_index, shuffle=False):
    collate_fn = get_collate_fn(pad_index)
    data_loader = torch.utils.data.DataLoader(
        dataset=dataset,
        batch_size=batch_size,
        collate_fn=collate_fn,
        shuffle=shuffle,
    )
    return data_loader

# %%
# 为了发挥最大性能，batch_size应该适合GPU的内存
# 训练时数据设置为shuffle=True，可以得到更稳定的结果，valid和test上没必要shuffle
batch_size = 128

train_data_loader = get_data_loader(train_data, batch_size, pad_index, shuffle=True)
valid_data_loader = get_data_loader(valid_data, batch_size, pad_index)
test_data_loader = get_data_loader(test_data, batch_size, pad_index)

# %%
# 展示数据表明被处理后的数据是按列排布的
# for data in train_data_loader:
# print(data)
# Out:
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4,   4,  46,  ...,   4,   4,   4],
#         [ 14,   9, 120,  ...,  14, 224,  33],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  8,   5,   8,  ...,   8,   5,   5],
#         [ 16,  13,  16,  ...,  16, 550,  25],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[ 0,  0,  0,  ...,  0,  0,  0],
#         [ 4, 46,  4,  ...,  4,  4, 24],
#         [34,  9,  9,  ..., 24,  9, 55],
#         ...,
#         [ 3,  3,  3,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  5,   5,   5,  ...,   5,   6,   5],
#         [ 26,  13,  13,  ..., 177,  13,  66],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4, 251,   4,  ...,   4,   4,  33],
#         [ 24,  19,  34,  ...,  70,   9, 436],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  5, 216,   5,  ...,   5,   5,   5],
#         [ 96,  41,  26,  ...,  70,  13,  25],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 16,   4,   4,  ...,   4,  50,   4],
#         [ 30,  53,   9,  ..., 122,   2,  35],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 18,   5,   5,  ...,   5,  45,   5],
#         [ 30,  70, 116,  ..., 551,   9,  32],
#         ...,
#         [ 48,   3,   4,  ...,   3,   3,   3],
#         [  4,   3,   1,  ...,   3,   3,   3],
#         [  1,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  7,   4,   4,  ...,   4,   4,   4],
#         [120,  55,  64,  ..., 625,  34,  14],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 17,   5,   8,  ...,   5,   5,   8],
#         [165,  49, 173,  ..., 683,  26,  16],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [860, 176,   4,  ...,   4,   4,  19],
#         [ 24,  17,  14,  ...,   9,  14,  32],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [492,  28,   8,  ...,   5,   8,  73],
#         [ 80, 144,  16,  ...,  13,  16,  53],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4,   4, 216,  ...,  19,  48,  16],
#         [  9,   9, 228,  ...,  17,  63, 778],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  5,   5, 298,  ...,  73,  43,  18],
#         [ 13,  13,   9,  ...,  52,  65,  30],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[ 0,  0,  0,  ...,  0,  0,  0],
#         [ 4,  4,  7,  ...,  4,  4,  4],
#         [ 9,  9, 31,  ..., 38, 38,  9],
#         ...,
#         [ 3,  3,  3,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5,    5,    8,  ...,   76,   17,    5],
#         [  13,   13,  955,  ...,   26, 1495,   13],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   4,    4,   16,  ...,    4,    6, 4723],
#         [   9,    9, 1506,  ..., 5011,  459,   12],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5,    5,   18,  ...,    5,   59,   30],
#         [  13,   13, 2944,  ...,  116,    6, 1008],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   4,    4,    4,  ...,    4,    4,  355],
#         [  35,  188, 2818,  ...,   14,  170,   11],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5,    5,    5,  ...,    8,    5,    8],
#         [4830,  435, 7007,  ...,   16, 1332,   36],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [251,  48,   4,  ...,   4,  48,  21],
#         [ 19, 112,  24,  ...,  38, 127,  86],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [ 216,   43,    5,  ...,    8,   43,    8],
#         [  41,  121,   70,  ...,   36,   80, 1485],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   4,    4,    4,  ..., 3123,   16,    4],
#         [  24,  120, 5223,  ..., 1827,  130,   35],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5,    8,    5,  ..., 2074,   18,    5],
#         [  96,   16,   32,  ..., 1584, 3113,   32],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[ 0,  0,  0,  ...,  0,  0,  0],
#         [64,  4,  4,  ...,  4,  4,  4],
#         [37, 29, 14,  ..., 64, 38, 38],
#         ...,
#         [ 3,  3,  3,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3]]), 'de_ids': tensor([[ 0,  0,  0,  ...,  0,  0,  0],
#         [ 8,  8,  8,  ...,  8, 76,  8],
#         [67, 67, 16,  ..., 67, 41, 36],
#         ...,
#         [ 3,  3,  3,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 16,   4,  19,  ...,   4,  21,   4],
#         [ 59,   9,  17,  ..., 170,   2,  38],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [  18,    5,   54,  ...,    5,    5,    8],
#         [1354,   13, 1336,  ..., 1332, 1050,   36],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 24,   7,   4,  ...,   4,   4,   4],
#         [ 14,  14,  34,  ...,  34,  31, 268],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  8,  17,   5,  ...,   5,   5,   5],
#         [ 26,  16,  26,  ...,  26, 251, 320],
#         ...,
#         [  1,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4,   4,   4,  ...,   4,   4,   4],
#         [  9,  26, 120,  ...,   9,  24, 985],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5,    5,    8,  ...,    5,    5,    7],
#         [  13, 3008,  165,  ...,   13,   96, 3512],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 63,   4,   4,  ...,   4, 113,   4],
#         [ 20,  24,   9,  ...,  26, 196,  14],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 65,   5,   5,  ...,   5,  76,   8],
#         [  9,  66,  13,  ..., 243,  65,  16],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 21,  16,   4,  ...,  16,  46, 176],
#         [ 86, 360,   9,  ...,  63,  33,  17],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5,   18,    5,  ...,   18,    5,  231],
#         [3247,   30,   13,  ...,   65,   25,   84],
#         ...,
#         [   3,    3,    3,  ...,    3,    1,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   4,    4,    7,  ...,   19,    4,   48],
#         [  34,   87, 2222,  ...,    6,   14,   70],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  5, 191,  15,  ...,  41,   8,  43],
#         [ 26,  41, 503,  ...,  11,  16, 103],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   4,    4,   21,  ...,    4,    4,    4],
#         [  24,   14, 4037,  ...,  795,   64,    9],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  5,   8,   5,  ...,   5,   8,   5],
#         [ 66,  16,   2,  ..., 308,  67,  13],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4,   4,  16,  ...,   7,   4,  16],
#         [  9,   9, 104,  ...,  26, 429, 360],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  5,   5,  18,  ...,  15,   5,  18],
#         [ 13,  13,  25,  ..., 243, 842,  30],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4,  16,   4,  ...,   7,   4,   4],
#         [164,  19,  33,  ...,   9,  24,  14],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5,   18,    5,  ...,    5,    5,    8],
#         [1410,   54,   25,  ...,  173,   70,   16],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 16,   4,   4,  ...,   4,   4,  16],
#         [ 30,   9,  87,  ...,   9,  53, 228],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [  18,    5,    8,  ...,    5,    5,   18],
#         [  30,   13, 1189,  ...,   13,   66,  241],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 16,  16,   4,  ...,   4,   4,   4],
#         [ 50,  30, 120,  ...,  14,  24,   9],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 18,  18,   8,  ...,   8,   5,   5],
#         [ 45,  30, 165,  ...,  16,  70,  13],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4,   4, 667,  ...,   4,   4,  16],
#         [510,  33, 158,  ...,  38,  64, 360],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   5],
#         [  3,   3,   3,  ...,   3,   3,   1],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5,    5,    5,  ...,    8,    5,   18],
#         [ 502,   25, 1063,  ...,   36,  431,   80],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4,   4,   4,  ...,  21,   4,   4],
#         [192,  38,  64,  ..., 324,  55,  33],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5,    8,    8,  ...,    8,    5,    5],
#         [6072,   36,   67,  ..., 1518,   49,   25],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[ 0,  0,  0,  ...,  0,  0,  0],
#         [ 4,  4,  4,  ...,  4,  4,  4],
#         [ 9,  9, 64,  ...,  9, 14, 14],
#         ...,
#         [ 3,  3,  3,  ...,  3, 44,  3],
#         [ 3,  3,  3,  ...,  3,  5,  3],
#         [ 3,  3,  3,  ...,  3,  1,  3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5,    5,    5,  ...,    5,    8,    8],
#         [  13,   13,  431,  ...,   13,   16,   16],
#         ...,
#         [   3,    3,    3,  ...,    3, 1173,    3],
#         [   3,    3,    3,  ...,    3,    4,    3],
#         [   3,    3,    3,  ...,    3,    1,    3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [480,  46,   4,  ...,   4,   7,  38],
#         [  6, 120,   9,  ...,  38,  33,  12],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  5,   8,   5,  ...,   8,  39,   8],
#         [986,  16,  13,  ...,  36,  25,  36],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [  19,   19,    4,  ..., 1078,    4,    4],
#         [  36,  669,    9,  ..., 1223,  791,    9],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,  156],
#         [   3,    3,    3,  ...,    3,    3,    5],
#         [   3,    3,    3,  ...,    3,    3,    1]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 54,  73,   5,  ..., 687,   8,   5],
#         [ 52,   9,  13,  ..., 469, 346,  13],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   4],
#         [  3,   3,   3,  ...,   3,   3,   1],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4,  21,   4,  ...,  16,   4,  16],
#         [  9, 115,  55,  ...,  30,   9, 127],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5,    5,    5,  ...,   18,    5,   18],
#         [  13, 1259,   49,  ...,   30,   13,   80],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 16,   4,   4,  ...,   4,  21,   4],
#         [360,  64,   9,  ...,   9, 106,  53],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [  18,    8,    5,  ...,    5,   21,    5],
#         [1256,   67,   13,  ...,   13,    6,   66],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 16,   4,   4,  ...,   4,   4,  50],
#         [ 19, 674,  64,  ...,   9,   9,   6],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 18,   5,   8,  ...,   5,   5,  45],
#         [ 73, 580,  67,  ...,  13,  13, 109],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4, 113,   4,  ...,   9,   4,  16],
#         [ 34,  19,   9,  ...,  13,   9, 104],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  5,  20,   5,  ...,   5,   5,  18],
#         [  2, 670,  13,  ...,  13,  13,  25],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [  16,    4, 3119,  ...,    4,   19,    4],
#         [  30,   24,   73,  ...,   14,   17,   24],
#         ...,
#         [   3,    1,    3,  ...,    1,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [  18,    8,    5,  ...,    8,   54,    5],
#         [  30,   26, 3831,  ...,   16,  157,  177],
#         ...,
#         [   3,    1,    4,  ...,    3,    3,    3],
#         [   3,    3,    1,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 21,   4,   4,  ...,   6,   4,   4],
#         [387,  14, 161,  ...,   7,  14,   9],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   8,    8,    5,  ...,   20,    8,    5],
#         [ 330,   16,  568,  ..., 7428,   16,   13],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4,   4,   4,  ..., 110,   4,   4],
#         [  9,   9,   9,  ..., 216,  24,  24],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  5,   5,   5,  ..., 105,   5,   5],
#         [ 13,  13,  13,  ..., 298,  26,  66],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[ 0,  0,  0,  ...,  0,  0,  0],
#         [ 6,  4,  4,  ...,  4,  4,  4],
#         [43, 33, 53,  ..., 34, 34, 24],
#         ...,
#         [ 3,  3,  3,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  5,   5,   5,  ...,   5,   5,   5],
#         [ 13,  25,  66,  ...,  26,  26, 177],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   9,    4,    4,  ...,  850,    4,  113],
#         [  57,    9,  122,  ...,   17,   38, 3812],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5,    5,    5,  ...,  691,    8,   76],
#         [  20,   13,  385,  ...,  279,   36, 1143],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [  35,    4,    4,  ...,    4,   16,    7],
#         [2620,   38,  120,  ...,   34,  112,   14],
#         ...,
#         [   3,    3,    1,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  5,   8,   8,  ...,   5,  18,  17],
#         [ 32,  36, 165,  ...,  26, 121,  16],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 16,   4,  16,  ...,   6,  39,   4],
#         [216,   9,  53,  ..., 209, 428,  53],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [  18,    5,   18,  ...,   12, 7406,    5],
#         [ 298,   13,  103,  ...,  930,  151,   66],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4,   4,  16,  ..., 202,   4,   4],
#         [ 53,  53, 196,  ...,  19,  24,  53],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5,    5,   18,  ...,  191,    5,    5],
#         [  66,   66, 1237,  ...,   54,   70,   70],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4,   4,   4,  ...,   4,   4,  14],
#         [  9,  53, 560,  ...,  38,   9,   6],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[ 0,  0,  0,  ...,  0,  0,  0],
#         [ 5,  5,  5,  ...,  8,  5,  8],
#         [13, 70,  2,  ..., 36, 13, 16],
#         ...,
#         [ 3,  3,  1,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  7,   4,   4,  ...,   4,  16,  16],
#         [ 50,  14,   9,  ...,   9,  50, 106],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 17,   8,   5,  ...,   5,  18,  18],
#         [ 45,  16,  13,  ...,  13,  45, 315],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   4,    4,    4,  ...,   16,    4,   16],
#         [ 573, 1634,   25,  ...,  216,    9, 3007],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5,    5,    5,  ...,   18,    5,   18],
#         [ 116, 1995,  150,  ...,  298,   13, 6598],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [2552,  388,    4,  ...,    4,    7,    4],
#         [ 254,   24,    9,  ...,  353,   48,    9],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  2,   5,   5,  ...,  12,  17,   5],
#         [279,  96,  13,  ...,   6,  43,  13],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 21,   4,   4,  ..., 998,   4,   7],
#         [115,   9, 683,  ...,   9,  14,  33],
#         ...,
#         [  3,   3,   3,  ...,   3,  85,   3],
#         [  3,   3,   3,  ...,   3,   5,   3],
#         [  3,   3,   3,  ...,   3,   1,   3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   8,    5,    5,  ..., 3500,    8,   39],
#         [ 174,  516, 1144,  ..., 1941,   16,   25],
#         ...,
#         [   3,    3,    3,  ...,    3,  904,    3],
#         [   3,    3,    3,  ...,    3,    4,    3],
#         [   3,    3,    3,  ...,    3,    1,    3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   4,    4,   53,  ...,    4,    4,  110],
#         [   9,   14,   34,  ...,    9,  496, 1824],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5,    8,    5,  ...,    5,    8,  105],
#         [ 173,   16,   70,  ...,   13,  364, 3191],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4,  21,   4,  ...,  16,   4,   4],
#         [ 38, 554,  55,  ...,  50,   9,  14],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [  17,    8,    5,  ...,   12,    5,    8],
#         [ 949, 1103,   49,  ...,    6,   13,   16],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  9, 990,   4,  ...,   4,  16,   7],
#         [ 45,   2,   9,  ..., 213,  63,   9],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5, 3599,    5,  ...,    5,   18,   15],
#         [  13, 3881,   13,  ...,  942,   65,   13],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [3785,    4,    4,  ...,    7,    4,    4],
#         [ 137,    9, 1281,  ...,   34,  606,   59],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [3231,    5,    5,  ...,   15,    8,    5],
#         [  57,   13, 2936,  ...,   26, 1988,  533],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  9,  16,   4,  ...,   4,   4,   4],
#         [ 78, 639,  33,  ...,  14, 999, 188],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5,   18,    5,  ...,    8,    8,    5],
#         [  13,    2,   25,  ...,   16, 1047,  435],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   4,  202,    4,  ...,    4,    4,    4],
#         [1585,   19,    9,  ...,    9,   38,  133],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5,  191,    5,  ...,    5,    8,    8],
#         [1574,   41,   13,  ...,   13,   36,  692],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   4,  549,    4,  ...,    4,    4,    4],
#         [1012,  783,   14,  ...,  178,  386,   84],
#         ...,
#         [   3,    3,    3,  ...,    3,   84,    3],
#         [   3,    3,    3,  ...,    3,    5,    3],
#         [   3,    3,    3,  ...,    3,    1,    3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5,  416,    8,  ...,    5,    5,    5],
#         [ 503,    2,   16,  ..., 1378,   66,    2],
#         ...,
#         [   3,    3,    3,  ...,    3,  142,    3],
#         [   3,    3,    3,  ...,    3,    4,    3],
#         [   3,    3,    3,  ...,    3,    1,    3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   4,    4,   21,  ...,    4,    4,    4],
#         [1491,    9,  233,  ...,    9,    9,   14],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5,    5,    5,  ...,    5,    5,    8],
#         [1809,   13, 1259,  ...,   13,   13,   16],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 19,   4,   4,  ...,   4, 183,   7],
#         [  8, 120,  55,  ...,   9,   2,  24],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [  76,    8,    5,  ...,    5,    8,   15],
#         [  41, 4797,   49,  ...,   13, 7513,   26],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   4,    4,    4,  ...,   48,   16,    4],
#         [3731,   34,   38,  ...,  104,   30,   34],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[ 0,  0,  0,  ...,  0,  0,  0],
#         [ 8,  5,  8,  ..., 43, 18,  5],
#         [ 2, 26, 36,  ..., 25, 30, 26],
#         ...,
#         [ 3,  3,  3,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4,  48,   4,  ...,   4,   4,   7],
#         [ 70, 699,   9,  ...,  34,  64, 282],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[ 0,  0,  0,  ...,  0,  0,  0],
#         [ 5, 43,  5,  ...,  5,  8, 15],
#         [70,  2, 13,  ..., 26, 67, 32],
#         ...,
#         [ 3,  3,  3,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4,   4,   4,  ...,   4,   4,   4],
#         [  9,  64, 188,  ...,  25, 870,  64],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5,    8,    5,  ...,    5,    5,    8],
#         [3487,   67,  435,  ...,  150,  490,   67],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   4,    4,   16,  ...,    4,    4,   16],
#         [   9, 4729,  360,  ..., 2409,  467,   61],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5,    5,   18,  ...,    5,    5,   18],
#         [  13, 2212,   30,  ...,    2,  954,  515],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[ 0,  0,  0,  ...,  0,  0,  0],
#         [ 7, 16, 16,  ...,  9,  4,  4],
#         [61, 24, 30,  ...,  8, 33,  9],
#         ...,
#         [ 3,  3,  3,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  5,  18,  18,  ...,   5,   5,   5],
#         [171,  80,  30,  ...,  13,  25,  13],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [2482,  334,    4,  ..., 1146,   16,   19],
#         [  15,   49,    9,  ...,   19,   24,  400],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [ 698,    5,    5,  ..., 1904,   18,   54],
#         [   9,   13,   13,  ...,   41,  103,  928],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4,   4,   4,  ...,   4,  74,   7],
#         [  9,   9,  55,  ...,  24, 456,  24],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5,    5,    5,  ...,    5,  221,   15],
#         [  13,   13,   49,  ...,   70, 1399,   26],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [  21,    4,    4,  ...,    4,    4,    4],
#         [ 697,    2,   26,  ...,  153,   14, 1466],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  5,   5,   5,  ...,   5,   8,   5],
#         [773, 241, 114,  ..., 164,  16,  13],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [  16,    4,   21,  ...,    7,  114,    4],
#         [ 104,    9,  233,  ...,   26,  120,   34],
#         ...,
#         [   3, 2052,    3,  ...,    3,    3,    3],
#         [   3,    5,    3,  ...,    3,    3,    3],
#         [   3,    1,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 18,   5,   8,  ...,  15, 492,   5],
#         [ 25,  13, 174,  ..., 243, 165,  26],
#         ...,
#         [  3, 941,   3,  ...,   3,   3,   3],
#         [  3,   4,   3,  ...,   3,   3,   3],
#         [  3,   1,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [ 860,   16,    4,  ...,    4,  251,    4],
#         [  53, 3650,  133,  ...,   14,   30,    9],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [492,  18,   5,  ...,   8, 216,   5],
#         [112, 174, 876,  ...,  16,  30,  13],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 21,   4,  16,  ...,   4,   4,   2],
#         [145,   9,  30,  ..., 154,   9,  36],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  5,   5,  18,  ...,   5,   5,   2],
#         [272,  13,  30,  ..., 116,  13,  29],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4,   4,   4,  ...,  21,   4, 110],
#         [355,  55,  14,  ..., 145,  14,  19],
#         ...,
#         [  5,   3,   3,  ...,   3,   3,   3],
#         [  1,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  8,   5,   8,  ...,   8,   8, 105],
#         [323,  49,  16,  ..., 390,  16,  41],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4,   4,   4,  ...,   4,   4,   4],
#         [ 14, 388,  33,  ...,   9,  38,   9],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  8,   5,   5,  ...,   5,   8,   5],
#         [ 16,  13,  25,  ..., 161,  36,  13],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   4, 1835,   53,  ...,  110,    4,  480],
#         [  14,  188,   33,  ...,   30,    9,  179],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   8,    5,    5,  ...,  105,    5,    5],
#         [  16, 2032,   66,  ...,   30,   13,  782],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   4,    9,   16,  ...,    4,    4,    4],
#         [  14,    6, 1133,  ...,   25,    9,   24],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  8,   5,  18,  ...,   5,   5,   5],
#         [ 16,  13,   2,  ..., 150,  13, 177],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   4,    4,   33,  ...,    4,    4,  110],
#         [   9,   14,    6,  ...,  388,   24, 2070],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5,    8,    5,  ...,    5,    8,  105],
#         [  13,   16,   25,  ...,  298,   26, 1143],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   4,   30,    4,  ...,  290,   21,    7],
#         [  24,   37,   14,  ...,  585, 1354,   70],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  5,  30,   8,  ..., 325,   5,  15],
#         [ 96,  57,  16,  ...,   9,   2, 103],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   4,  998, 1812,  ...,   16,   29,   21],
#         [  24, 2912,    7,  ...,   30, 4842,  697],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5, 3275,   39,  ...,   18,   12,    5],
#         [  70,    7,  455,  ...,   30,    6,  773],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[ 0,  0,  0,  ...,  0,  0,  0],
#         [ 4,  4,  4,  ...,  4,  4,  4],
#         [14, 59, 38,  ...,  9,  9,  9],
#         ...,
#         [ 3,  3,  3,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  8,   5,  76,  ...,   5,   5,   5],
#         [ 16, 427,  41,  ...,  13,  13,  13],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 16,   4,  21,  ...,   4,  48, 110],
#         [ 19,   9, 145,  ...,   9, 112, 660],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 18,   5,   8,  ...,   5,  43, 105],
#         [ 41,  13, 390,  ...,  13, 121, 537],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [2555,    4,    4,  ...,   16,  209,   24],
#         [ 585,   35,    9,  ..., 1078,   10, 3157],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   8,    5,    5,  ...,   18,    5,    5],
#         [2424,   32,   13,  ...,  308,   96,   96],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  7,   4,   4,  ...,   4,   4,   4],
#         [  9, 485, 855,  ..., 188, 183,   9],
# ...
#         [24,  9, 55,  ..., 14, 70,  9],
#         ...,
#         [ 3,  3,  3,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3]]), 'de_ids': tensor([[ 0,  0,  0,  ...,  0,  0,  0],
#         [43,  5,  5,  ...,  8,  5,  5],
#         [26, 13, 49,  ..., 16, 70, 13],
#         ...,
#         [ 3,  3,  3,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4,   4,   4,  ...,  48,  16,   4],
#         [183,  38,  64,  ...,  30,  30,   9],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  8,   8, 325,  ...,  43,  18,   5],
#         [ 16,  36, 526,  ...,  30,  30,  13],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 14,   2,   4,  ...,   4,   4,   4],
#         [ 22,   2,  14,  ..., 161,  24,  38],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  8,   2,   8,  ...,   5,   5,   8],
#         [ 16,   2,  16,  ..., 371,  66,  36],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   4, 5824,   21,  ...,  313,    4,  956],
#         [ 939,   15, 1183,  ..., 2579,    9,   24],
#         ...,
#         [   3,  925,    3,  ...,    3,    3,    3],
#         [   3,    5,    3,  ...,    3,    3,    3],
#         [   3,    1,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5,  278,    5,  ...,   99,    5,    5],
#         [1740,    9,    2,  ..., 1388,   13,  177],
#         ...,
#         [   3,   31,    3,  ...,    3,    3,    3],
#         [   3,    4,    3,  ...,    3,    3,    3],
#         [   3,    1,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [1774,  860,    4,  ...,   16,    4,   48],
#         [5707,   17,  153,  ...,  112,    9,  112],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [1695, 1222,    5,  ...,   18,    5,   43],
#         [ 459,   84,  164,  ...,  121,   13,  121],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [  21,   16, 1919,  ...,    4,    4,    4],
#         [ 145,   30,   45,  ...,    9,    9,  174],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  8,  18, 980,  ...,   5,   5,   5],
#         [390,  30,  11,  ...,  13,  13, 452],
#         ...,
#         [  1,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 34,   4,   4,  ...,   4,   4,   4],
#         [  6, 323,  64,  ...,  34, 267,  14],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  5,   5,   8,  ...,   5,   8,   8],
#         [ 26, 241,  67,  ...,  26, 732,  16],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4,  16,   4,  ...,  16,  16,   4],
#         [ 24, 112, 224,  ...,  70, 123,  14],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  5,  18,   5,  ...,  18,  18,   8],
#         [ 70, 121, 550,  ..., 103, 371,  16],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 16,   4,  16,  ...,   4,   4,  19],
#         [ 25,   9, 196,  ...,   9,   9, 359],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 18,   5,  18,  ...,   5,   5,  54],
#         [253,  13,  65,  ...,  13,  13,   2],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [ 602,    4,   21,  ...,   16,    9,   21],
#         [   2,   53, 1196,  ...,   30,   41,  433],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [625,   5, 325,  ...,  18,   5,   8],
#         [  2,  70, 303,  ...,  30,  13,   2],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4,   4,   4,  ...,  16,  16,   4],
#         [ 26,  55,   9,  ...,  24, 486,  14],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  5,   5,   5,  ...,  18,  18,   8],
#         [522,  49,  13,  ..., 103, 805,  16],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4, 110,  46,  ...,   7,   4, 110],
#         [ 14, 127,   9,  ...,   9,  64, 127],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  8, 105,   5,  ...,   5,   8, 105],
#         [ 16,  80,  13,  ...,  13,  67,  80],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4,  46,   4,  ...,   7, 417, 110],
#         [ 14,   9,  26,  ..., 196, 353,  19],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   8,    5,    5,  ...,   65,   18,  105],
#         [  16,   13,  114,  ..., 1104,    2,   41],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [855,  16,   4,  ...,   4,  48,   4],
#         [ 31, 360,   9,  ..., 295,  30,  64],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5,   18,    5,  ...,    5,   43,    8],
#         [1225,   30,   13,  ...,  618,   30,   67],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4,   4,   4,  ...,   4,   4,   4],
#         [  9,  38,  55,  ...,   9, 381, 699],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5,    8,    5,  ...,    5,    8,    5],
#         [  13,   36,   49,  ...,   13,  168, 2510],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 21,  14,   4,  ...,   4,   4,  16],
#         [233,   6,  53,  ..., 868,  24,  53],
#         ...,
#         [  3,   3,   3,  ...,   3,   3, 478],
#         [  3,   3,   3,  ...,   3,   3,   5],
#         [  3,   3,   3,  ...,   3,   3,   1]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  5,  16,   5,  ...,   5,   5,  18],
#         [130,   7,  66,  ..., 308,  66, 103],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 48,   4,   4,  ...,   4,  19,  30],
#         [ 63,  35,  64,  ...,   9,  78, 400],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [  43,    5,    8,  ...,    5,   41,   73],
#         [  65,   32,   67,  ...,   13,  724, 2373],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [202,   4,   4,  ...,   7,   4,  16],
#         [ 90,  14,   9,  ..., 348,  14,  30],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [191,   8,   5,  ...,  39,   8,  18],
#         [199,  16,  13,  ...,  49,  16,  30],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4,   4,   4,  ..., 110,   4, 209],
#         [ 55, 105,  55,  ...,  30,  53, 839],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  5,   5,   5,  ..., 105,   5, 948],
#         [ 49, 269,  49,  ...,  30,  66, 209],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [ 21,  21,   4,  ...,  16,   4,  19],
#         [145, 106,  53,  ...,  50,  14,  17],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  5,   8,   5,  ...,  18,   8,  73],
#         [272, 315,  66,  ...,  45,  16, 157],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [251,   4,   4,  ...,   4,   4,   9],
#         [ 19,  34,  24,  ...,  14, 353, 273],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [ 216,    5,    5,  ...,    8,    5,    5],
#         [  54,   26,   96,  ...,   16, 1035,   13],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4,  16,   9,  ...,  21,  33,  19],
#         [  9,  19,   6,  ..., 145, 758,  36],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5,   18,    5,  ...,    5,    5,   76],
#         [  13,  490,   13,  ..., 1675,   25,   41],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   4,  113,  417,  ...,   19,   16,   24],
#         [  14,   19,  196,  ..., 1924,   26,   19],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   8,   76, 1086,  ...,   54,   18,   26],
#         [  16,   54,   65,  ...,  693,  243,   73],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4,   4,   4,  ...,  16, 176,  16],
#         [  9,  70, 425,  ...,  50,  10,  19],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  5,   8,   8,  ...,  18,   5,  18],
#         [ 13, 103,   2,  ...,  45, 308, 363],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]])}
# {'en_ids': tensor([[  0,   0,   0,  ...,   0,   0,   0],
#         [  4,   4,   7,  ...,   4, 244, 457],
#         [  9,  14, 491,  ...,  14,  17, 778],
#         ...,
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3],
#         [  3,   3,   3,  ...,   3,   3,   3]]), 'de_ids': tensor([[   0,    0,    0,  ...,    0,    0,    0],
#         [   5,    8,   15,  ...,    8,   99,  413],
#         [  13,   16, 3659,  ...,   16,   84,  510],
#         ...,
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3],
#         [   3,    3,    3,  ...,    3,    3,    3]])}
# {'en_ids': tensor([[ 0,  0,  0,  ...,  0,  0,  0],
#         [ 4,  4,  4,  ...,  4,  4,  4],
#         [ 9,  9,  9,  ...,  9,  9, 70],
#         ...,
#         [ 3,  3,  3,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3]]), 'de_ids': tensor([[ 0,  0,  0,  ...,  0,  0,  0],
#         [ 5,  5,  5,  ...,  5,  5,  5],
#         [13, 13, 13,  ..., 13, 13, 70],
#         ...,
#         [ 3,  3,  3,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3],
#         [ 3,  3,  3,  ...,  3,  3,  3]])}
